# %%
# !pip install pandas
# !pip install matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Old results

# %%
# !ls
# Out:
#  analyse.ipynb		    res_mult_20000.csv	       res_mult_40000.csv
# 'res_mult_20000 copy.csv'  'res_mult_40000 copy.csv'

# %%
res_red = pd.read_csv("res_mult_20000 copy.csv", delimiter=";")

res_full = pd.read_csv("res_mult_40000 copy.csv", delimiter=";")

# %%
plt.plot(res_red["Amount_of_threads"], res_red["Speedup"], markersize=7, marker='o')
plt.plot(res_full["Amount_of_threads"], res_full["Speedup"], markersize=7, marker='o')
plt.plot([0,10], [0,10])
plt.grid()
plt.xlabel('Threads')
plt.ylabel('Speedup')
plt.legend(["len_20000", "len_40000"])
plt.show()
